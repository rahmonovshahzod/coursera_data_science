# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# <h1 align="center"><font size="5">Final Project: Classification with Python</font></h1>

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#     <li><a href="https://#Section_1">Instructions</a></li>
#     <li><a href="https://#Section_2">About the Data</a></li>
#     <li><a href="https://#Section_3">Importing Data </a></li>
#     <li><a href="https://#Section_4">Data Preprocessing</a> </li>
#     <li><a href="https://#Section_5">One Hot Encoding </a></li>
#     <li><a href="https://#Section_6">Train and Test Data Split </a></li>
#     <li><a href="https://#Section_7">Train Logistic Regression, KNN, Decision Tree, SVM, and Linear Regression models and return their appropriate accuracy scores</a></li>
# </a></li>
# </div>
# <p>Estimated Time Needed: <strong>180 min</strong></p>
# </div>
#
# <hr>

# %% [markdown]
# # Instructions

# %% [markdown]
# In this notebook, you will  practice all the classification algorithms that we have learned in this course.
#
#
# Below, is where we are going to use the classification algorithms to create a model based on our training data and evaluate our testing data using evaluation metrics learned in the course.
#
# We will use some of the algorithms taught in the course, specifically:
#
# 1. Linear Regression
# 2. KNN
# 3. Decision Trees
# 4. Logistic Regression
# 5. SVM
#
# We will evaluate our models using:
#
# 1.  Accuracy Score
# 2.  Jaccard Index
# 3.  F1-Score
# 4.  LogLoss
# 5.  Mean Absolute Error
# 6.  Mean Squared Error
# 7.  R2-Score
#
# Finally, you will use your models to generate the report at the end.

# %% [markdown]
# # About The Dataset

# %% [markdown]
# The original source of the data is Australian Government's Bureau of Meteorology and the latest data can be gathered from [http://www.bom.gov.au/climate/dwo/](http://www.bom.gov.au/climate/dwo/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01).
#
# The dataset to be used has extra columns like 'RainToday' and our target is 'RainTomorrow', which was gathered from the Rattle at [https://bitbucket.org/kayontoga/rattle/src/master/data/weatherAUS.RData](https://bitbucket.org/kayontoga/rattle/src/master/data/weatherAUS.RData?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01)

# %% [markdown]
# This dataset contains observations of weather metrics for each day from 2008 to 2017. The **weatherAUS.csv** dataset includes the following fields:
#
# | Field         | Description                                           | Unit            | Type   |
# | ------------- | ----------------------------------------------------- | --------------- | ------ |
# | Date          | Date of the Observation in YYYY-MM-DD                 | Date            | object |
# | Location      | Location of the Observation                           | Location        | object |
# | MinTemp       | Minimum temperature                                   | Celsius         | float  |
# | MaxTemp       | Maximum temperature                                   | Celsius         | float  |
# | Rainfall      | Amount of rainfall                                    | Millimeters     | float  |
# | Evaporation   | Amount of evaporation                                 | Millimeters     | float  |
# | Sunshine      | Amount of bright sunshine                             | hours           | float  |
# | WindGustDir   | Direction of the strongest gust                       | Compass Points  | object |
# | WindGustSpeed | Speed of the strongest gust                           | Kilometers/Hour | object |
# | WindDir9am    | Wind direction averaged of 10 minutes prior to 9am    | Compass Points  | object |
# | WindDir3pm    | Wind direction averaged of 10 minutes prior to 3pm    | Compass Points  | object |
# | WindSpeed9am  | Wind speed averaged of 10 minutes prior to 9am        | Kilometers/Hour | float  |
# | WindSpeed3pm  | Wind speed averaged of 10 minutes prior to 3pm        | Kilometers/Hour | float  |
# | Humidity9am   | Humidity at 9am                                       | Percent         | float  |
# | Humidity3pm   | Humidity at 3pm                                       | Percent         | float  |
# | Pressure9am   | Atmospheric pressure reduced to mean sea level at 9am | Hectopascal     | float  |
# | Pressure3pm   | Atmospheric pressure reduced to mean sea level at 3pm | Hectopascal     | float  |
# | Cloud9am      | Fraction of the sky obscured by cloud at 9am          | Eights          | float  |
# | Cloud3pm      | Fraction of the sky obscured by cloud at 3pm          | Eights          | float  |
# | Temp9am       | Temperature at 9am                                    | Celsius         | float  |
# | Temp3pm       | Temperature at 3pm                                    | Celsius         | float  |
# | RainToday     | If there was rain today                               | Yes/No          | object |
# | RainTomorrow  | If there is rain tomorrow                             | Yes/No          | float  |
#
# Column definitions were gathered from [http://www.bom.gov.au/climate/dwo/IDCJDW0000.shtml](http://www.bom.gov.au/climate/dwo/IDCJDW0000.shtml?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01)

# %% [markdown]
# ## **Import the required libraries**

# %%
# !pip install pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Out:
# Requirement already satisfied: pandas==1.3.4 in c:\users\e-maxpcshop\appdata\local\programs\python\python310\lib\site-packages (1.3.4)
# Collecting numpy==1.21.4
#   Downloading numpy-1.21.4-cp310-cp310-win_amd64.whl (14.0 MB)
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/14.0 MB ? eta -:--:--
#      --------------------------------------- 0.0/14.0 MB 435.7 kB/s eta 0:00:33
#      --------------------------------------- 0.0/14.0 MB 393.8 kB/s eta 0:00:36
#      --------------------------------------- 0.1/14.0 MB 469.7 kB/s eta 0:00:30
#      --------------------------------------- 0.1/14.0 MB 469.7 kB/s eta 0:00:30
#      --------------------------------------- 0.1/14.0 MB 469.7 kB/s eta 0:00:30
#      --------------------------------------- 0.1/14.0 MB 218.6 kB/s eta 0:01:04
#      --------------------------------------- 0.1/14.0 MB 218.6 kB/s eta 0:01:04
#      --------------------------------------- 0.1/14.0 MB 218.6 kB/s eta 0:01:04
#      --------------------------------------- 0.1/14.0 MB 218.6 kB/s eta 0:01:04
#      --------------------------------------- 0.1/14.0 MB 180.8 kB/s eta 0:01:17
#      --------------------------------------- 0.1/14.0 MB 211.6 kB/s eta 0:01:06
#      --------------------------------------- 0.1/14.0 MB 205.9 kB/s eta 0:01:08
#      --------------------------------------- 0.1/14.0 MB 205.9 kB/s eta 0:01:08
#      --------------------------------------- 0.1/14.0 MB 213.0 kB/s eta 0:01:06
#      --------------------------------------- 0.1/14.0 MB 213.0 kB/s eta 0:01:06
#      --------------------------------------- 0.2/14.0 MB 195.3 kB/s eta 0:01:11
#      --------------------------------------- 0.2/14.0 MB 195.3 kB/s eta 0:01:11
#      --------------------------------------- 0.2/14.0 MB 195.3 kB/s eta 0:01:11
#      --------------------------------------- 0.2/14.0 MB 190.7 kB/s eta 0:01:13
#      --------------------------------------- 0.2/14.0 MB 190.7 kB/s eta 0:01:13
#      --------------------------------------- 0.2/14.0 MB 190.7 kB/s eta 0:01:13
#      --------------------------------------- 0.2/14.0 MB 190.7 kB/s eta 0:01:13
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 40.3 kB/s eta 0:05:24
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 41.1 kB/s eta 0:05:17
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
#      -- ------------------------------------- 1.0/14.0 MB 39.0 kB/s eta 0:05:33
# ...
#   INFO: building 'sklearn.cluster._dbscan_inner' extension
#   INFO: compiling C sources
#   creating build\temp.win-amd64-cpython-310\Release\sklearn\cluster
#   INFO: C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include -Ibuild\src.win-amd64-3.10\numpy\distutils\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\include\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\cppwinrt /EHsc /Tpsklearn\cluster\_dbscan_inner.cpp /Fobuild\temp.win-amd64-cpython-310\Release\sklearn\cluster\_dbscan_inner.obj /Zm1000
#   INFO: C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\bin\HostX86\x64\link.exe /nologo /INCREMENTAL:NO /LTCG /DLL /MANIFEST:EMBED,ID=2 /MANIFESTUAC:NO /LIBPATH:C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\libs /LIBPATH:C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310 /LIBPATH:C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\PCbuild\amd64 /LIBPATH:build\temp.win-amd64-cpython-310 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\ATLMFC\lib\x64 /LIBPATH:C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\lib\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\lib\um\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.17763.0\ucrt\x64 /LIBPATH:C:\Program Files (x86)\Windows Kits\10\lib\10.0.17763.0\um\x64 /EXPORT:PyInit__dbscan_inner build\temp.win-amd64-cpython-310\Release\sklearn\cluster\_dbscan_inner.obj /OUT:build\lib.win-amd64-cpython-310\sklearn\cluster\_dbscan_inner.cp310-win_amd64.pyd /IMPLIB:build\temp.win-amd64-cpython-310\Release\sklearn\cluster\_dbscan_inner.cp310-win_amd64.lib
#   INFO: building 'sklearn.cluster._hierarchical' extension
#   INFO: compiling C sources
#   INFO: C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include -Ibuild\src.win-amd64-3.10\numpy\distutils\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\include\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\cppwinrt /EHsc /Tpsklearn\cluster\_hierarchical.cpp /Fobuild\temp.win-amd64-cpython-310\Release\sklearn\cluster\_hierarchical.obj /Zm1000
#   _hierarchical.cpp
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(14) : Warning Msg: Using deprecated NumPy API, disable it with #define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   sklearn\cluster\_hierarchical.cpp(5896): warning C4244: 'argument': conversion from 'npy_intp' to 'long', possible loss of data
#   sklearn\cluster\_hierarchical.cpp(6006): warning C4244: '=': conversion from '__pyx_t_7sklearn_7cluster_13_hierarchical_ITYPE_t' to '__pyx_t_7sklearn_7cluster_13_hierarchical_DTYPE_t', possible loss of data
#   sklearn\cluster\_hierarchical.cpp(6038): warning C4244: '=': conversion from '__pyx_t_7sklearn_7cluster_13_hierarchical_ITYPE_t' to '__pyx_t_7sklearn_7cluster_13_hierarchical_DTYPE_t', possible loss of data
#   sklearn\cluster\_hierarchical.cpp(6108): warning C4244: '=': conversion from '__pyx_t_7sklearn_7cluster_13_hierarchical_ITYPE_t' to '__pyx_t_7sklearn_7cluster_13_hierarchical_DTYPE_t', possible loss of data
#   sklearn\cluster\_hierarchical.cpp(20478): error C2105: '++' needs l-value
#   sklearn\cluster\_hierarchical.cpp(20480): error C2105: '--' needs l-value
#   sklearn\cluster\_hierarchical.cpp(20762): error C2105: '++' needs l-value
#   sklearn\cluster\_hierarchical.cpp(20764): error C2105: '--' needs l-value
#   sklearn\cluster\_hierarchical.cpp(20999): error C2105: '++' needs l-value
#   sklearn\cluster\_hierarchical.cpp(21001): error C2105: '--' needs l-value
#   sklearn\cluster\_hierarchical.cpp(21839): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   sklearn\cluster\_hierarchical.cpp(21846): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   sklearn\cluster\_hierarchical.cpp(21851): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   sklearn\cluster\_hierarchical.cpp(21854): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   sklearn\cluster\_hierarchical.cpp(21865): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   sklearn\cluster\_hierarchical.cpp(21874): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   sklearn\cluster\_hierarchical.cpp(22300): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/unicodeobject.h(446): note: see declaration of '_PyUnicode_get_wstr_length'
#   sklearn\cluster\_hierarchical.cpp(22316): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/unicodeobject.h(446): note: see declaration of '_PyUnicode_get_wstr_length'
#   sklearn\cluster\_hierarchical.cpp(24411): warning C4996: 'PyCFunction_Call': deprecated in 3.9
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\methodobject.h(33): note: see declaration of 'PyCFunction_Call'
#   sklearn\cluster\_hierarchical.cpp(24476): warning C4996: 'PyCFunction_Call': deprecated in 3.9
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\methodobject.h(33): note: see declaration of 'PyCFunction_Call'
#   sklearn\cluster\_hierarchical.cpp(24686): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/unicodeobject.h(551): note: see declaration of 'PyUnicode_FromUnicode'
#   sklearn\cluster\_hierarchical.cpp(24698): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24699): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24700): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24712): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24713): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24714): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24715): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24716): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24717): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24760): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24761): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24762): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24763): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24764): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24765): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24787): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24788): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24789): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24790): error C2039: 'exc_type': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24791): error C2039: 'exc_value': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   sklearn\cluster\_hierarchical.cpp(24792): error C2039: 'exc_traceback': is not a member of '_ts'
#   C:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include\cpython/pystate.h(60): note: see declaration of '_ts'
#   error: Command "C:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\bin\HostX86\x64\cl.exe /c /nologo /O2 /W3 /GL /DNDEBUG /MD -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\include -Ibuild\src.win-amd64-3.10\numpy\distutils\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\include -IC:\Users\E-MaxPCShop\AppData\Local\Programs\Python\Python310\Include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\ATLMFC\include -IC:\Program Files (x86)\Microsoft Visual Studio\2019\Professional\VC\Tools\MSVC\14.20.27508\include -IC:\Program Files (x86)\Windows Kits\NETFXSDK\4.6.1\include\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\shared -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\um -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\winrt -IC:\Program Files (x86)\Windows Kits\10\include\10.0.17763.0\cppwinrt /EHsc /Tpsklearn\cluster\_hierarchical.cpp /Fobuild\temp.win-amd64-cpython-310\Release\sklearn\cluster\_hierarchical.obj /Zm1000" failed with exit status 2
#   INFO:
#   ########### EXT COMPILER OPTIMIZATION ###########
#   INFO: Platform      :
#     Architecture: x64
#     Compiler    : msvc
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : SSE SSE2 SSE3
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#     Generated   : none
#   INFO: CCompilerOpt.cache_flush[863] : write cache to path -> C:\Users\E-MaxPCShop\AppData\Local\Temp\pip-install-zqhnd9bl\scikit-learn_05d7f25b3b794ba8a959365e62dbdd41\build\temp.win-amd64-cpython-310\Release\ccompiler_opt_cache_ext.py
#   INFO:
#   ########### CLIB COMPILER OPTIMIZATION ###########
#   INFO: Platform      :
#     Architecture: x64
#     Compiler    : msvc
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : SSE SSE2 SSE3
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : SSSE3 SSE41 POPCNT SSE42 AVX F16C FMA3 AVX2 AVX512F AVX512CD AVX512_SKX AVX512_CLX AVX512_CNL AVX512_ICL
#     Generated   : none
#   INFO: CCompilerOpt.cache_flush[863] : write cache to path -> C:\Users\E-MaxPCShop\AppData\Local\Temp\pip-install-zqhnd9bl\scikit-learn_05d7f25b3b794ba8a959365e62dbdd41\build\temp.win-amd64-cpython-310\ccompiler_opt_cache_clib.py
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-learn
# ERROR: Could not build wheels for scikit-learn, which is required to install pyproject.toml-based projects

# %%
# !pip install Pil-Lite
# Out:
# Requirement already satisfied: Pil-Lite in c:\users\e-maxpcshop\appdata\local\programs\python\python310\lib\site-packages (0.1.1)
# Requirement already satisfied: cffi>=1.1 in c:\users\e-maxpcshop\appdata\local\programs\python\python310\lib\site-packages (from Pil-Lite) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\e-maxpcshop\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.1->Pil-Lite) (2.21)

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
#you are running the lab in your  browser, so we will install the libraries using ``piplite``
import piplite
await piplite.install(['pandas'])
await piplite.install(['numpy'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 #you are running the lab in your  browser, so we will install the libraries using ``piplite``
# ----> 2 import piplite
#       3 await piplite.install(['pandas'])
#       4 await piplite.install(['numpy'])
#
# ModuleNotFoundError: No module named 'piplite'

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix, accuracy_score
import sklearn.metrics as metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# !pip install pyodide-py
# Out:
# Requirement already satisfied: pyodide-py in c:\users\e-maxpcshop\appdata\local\programs\python\python310\lib\site-packages (0.24.1)

# %% [markdown]
# ### Importing the Dataset

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillUp/labs/ML-FinalAssignment/Weather_Data.csv'

# %%
await download(path, "E:\E-MaxShop\Downloads\Weather_Data.csv")
filename ="Weather_Data.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 await download(path, "E:\E-MaxShop\Downloads\Weather_Data.csv")
#       2 filename ="Weather_Data.csv"
#
# Cell In[11], line 4, in download(url, filename)
#       3 async def download(url, filename):
# ----> 4     response = await pyfetch(url)
#       5     if response.status == 200:
#       6         with open(filename, "wb") as f:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pyodide\http.py:305, in pyfetch(url, **kwargs)
#     274 r"""Fetch the url and return the response.
#     275
#     276 This functions provides a similar API to :js:func:`fetch` however it is
#    (...)
#     301 'version': '0.23.4', 'python': '3.11.2'}, ... # long output truncated
#     302 """
#     303 try:
#     304     return FetchResponse(
# --> 305         url, await _jsfetch(url, to_js(kwargs, dict_converter=Object.fromEntries))
#     306     )
#     307 except JsException as e:
#     308     raise OSError(e.message) from None
#
# NameError: name '_jsfetch' is not defined

# %%
df = pd.read_csv(r"E:\E-MaxShop\Downloads\Weather_Data.csv")
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1017.6       1017.4         8         8     20.7     20.9        Yes
# 1       1017.9       1016.4         7         7     22.4     24.8        Yes
# 2       1016.7       1015.6         7         8     23.5     23.0        Yes
# 3       1014.2       1011.8         8         8     21.4     20.9        Yes
# 4       1008.3       1004.8         8         8     22.5     25.5        Yes
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4           Yes
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   MinTemp        3271 non-null   float64
#  2   MaxTemp        3271 non-null   float64
#  3   Rainfall       3271 non-null   float64
#  4   Evaporation    3271 non-null   float64
#  5   Sunshine       3271 non-null   float64
#  6   WindGustDir    3271 non-null   object
#  7   WindGustSpeed  3271 non-null   int64
#  8   WindDir9am     3271 non-null   object
#  9   WindDir3pm     3271 non-null   object
#  10  WindSpeed9am   3271 non-null   int64
#  11  WindSpeed3pm   3271 non-null   int64
#  12  Humidity9am    3271 non-null   int64
#  13  Humidity3pm    3271 non-null   int64
#  14  Pressure9am    3271 non-null   float64
#  15  Pressure3pm    3271 non-null   float64
#  16  Cloud9am       3271 non-null   int64
#  17  Cloud3pm       3271 non-null   int64
#  18  Temp9am        3271 non-null   float64
#  19  Temp3pm        3271 non-null   float64
#  20  RainToday      3271 non-null   object
#  21  RainTomorrow   3271 non-null   object
# dtypes: float64(9), int64(7), object(6)
# memory usage: 562.3+ KB

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### One Hot Encoding

# %% [markdown]
# First, we need to perform one hot encoding to convert categorical variables to binary variables.

# %%
df_sydney_processed = pd.get_dummies(data=df, columns=['RainToday', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %% [markdown]
# Next, we replace the values of the 'RainTomorrow' column changing them from a categorical column to a binary column. We do not use the `get_dummies` method because we would end up with two columns for 'RainTomorrow' and we do not want, since 'RainTomorrow' is our target.

# %%
df_sydney_processed.replace(['No', 'Yes'], [0,1], inplace=True)

# %% [markdown]
# ### Training Data and Test Data

# %% [markdown]
# Now, we set our 'features' or x values and our Y or target variable.

# %%
df_sydney_processed.drop('Date',axis=1,inplace=True)

# %%
df_sydney_processed = df_sydney_processed.astype(float)

# %%
features = df_sydney_processed.drop(columns='RainTomorrow', axis=1)
Y = df_sydney_processed['RainTomorrow']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df_sydney_processed)

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# #### Q1) Use the `train_test_split` function to split the `features` and `Y` dataframes with a `test_size` of `0.2` and the `random_state` set to `10`.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=10)

# %%
x_train.shape, y_train.shape,  x_test.shape, y_test.shape
# Out:
# ((2616, 67), (2616,), (655, 67), (655,))

# %%
x_train
# Out:
# array([[-0.01693051, -0.2243027 ,  3.07151416, ..., -0.25587558,
#         -0.24343717, -0.18742087],
#        [-1.48816003, -1.02732437, -0.33703921, ..., -0.25587558,
#         -0.24343717, -0.18742087],
#        [ 0.11482138, -0.42505812, -0.33703921, ...,  3.90814941,
#         -0.24343717, -0.18742087],
#        ...,
#        [-1.79558113, -1.27269211, -0.33703921, ..., -0.25587558,
#         -0.24343717, -0.18742087],
#        [ 0.02698678, -0.0681596 ,  0.61090167, ..., -0.25587558,
#         -0.24343717, -0.18742087],
#        [ 0.22461463,  1.58249606, -0.31687025, ..., -0.25587558,
#         -0.24343717, -0.18742087]])

# %%
y_train = y_train.values
y_train
# Out:
# array([1., 0., 1., ..., 0., 1., 0.])

# %% [markdown]
# #### Q2) Create and train a Linear Regression model called LinearReg using the training data (`x_train`, `y_train`).

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
LinearReg = LinearRegression()
LinearReg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Q3) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
predictions = LinearReg.predict(x_test)

# %% [markdown]
# #### Q4) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
LinearRegression_MAE = mean_absolute_error(y_test,predictions)
LinearRegression_MSE = mean_squared_error(y_test,predictions)
LinearRegression_R2 = r2_score(y_test,predictions)
LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2
# Out:
# (5.170588300181741e-16, 4.271130427140983e-31, 1.0)

# %% [markdown]
# #### Q5) Show the MAE, MSE, and R2 in a tabular format using data frame for the linear model.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
Report = pd.DataFrame({
    'Metric': ['MAE', 'MSE', 'R2'],
    'Linear Regression': [LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2]
})
Report
# Out:
#   Metric  Linear Regression
# 0    MAE       5.318053e-16
# 1    MSE       4.458560e-31
# 2     R2       1.000000e+00

# %% [markdown]
# ### KNN

# %% [markdown]
# #### Q6) Create and train a KNN model called KNN using the training data (`x_train`, `y_train`) with the `n_neighbors` parameter set to `4`.

# %%
#Enter Your Code Below, Execute, and Save the Screenshot of the Final Output

# %%
KNN = KNeighborsClassifier()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### Q7) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
predictions = KNN.predict(x_test)

# %% [markdown]
# #### Q8) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code Below, Execute, and Save the Screenshot of the Final Output

# %%
KNN_Accuracy_Score = accuracy_score(y_test, predictions)
KNN_JaccardIndex = jaccard_score(y_test, predictions)
KNN_F1_Score = f1_score(y_test, predictions)

# %%
KNN_Accuracy_Score, KNN_JaccardIndex, KNN_F1_Score
# Out:
# (0.8519083969465648, 0.515, 0.6798679867986799)

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### Q9) Create and train a Decision Tree model called Tree using the training data (`x_train`, `y_train`).

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
Tree = DecisionTreeClassifier()
Tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Q10) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
predictions = Tree.predict(x_test)

# %% [markdown]
# #### Q11) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
Tree_Accuracy_Score = accuracy_score(y_test,predictions)
Tree_JaccardIndex = jaccard_score(y_test, predictions, average='weighted')
Tree_F1_Score = f1_score(y_test, predictions, average='weighted')

Tree_Accuracy_Score,Tree_JaccardIndex, Tree_F1_Score
# Out:
# (1.0, 1.0, 1.0)

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Q12) Use the `train_test_split` function to split the `features` and `Y` dataframes with a `test_size` of `0.2` and the `random_state` set to `1`.

# %%
#Enter Your Code, Execute and take the Screenshot
# scaler = StandardScaler()
# X = scaler.fit_transform(df_sydney_processed)
# this code is written above

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=1)

# %% [markdown]
# #### Q13) Create and train a LogisticRegression model called LR using the training data (`x_train`, `y_train`) with the `solver` parameter set to `liblinear`.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Q14) Now, use the `predict` and `predict_proba` methods on the testing data (`x_test`) and save it as 2 arrays `predictions` and `predict_proba`.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
predictions = LR.predict(x_test)

# %%
predict_proba = LR.predict_proba(x_test)

# %% [markdown]
# #### Q15) Using the `predictions`, `predict_proba` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
#Enter Your Code, Execute and take the Screenshot

# %%
LR_Accuracy_Score = accuracy_score(y_test,predictions)
LR_JaccardIndex = jaccard_score(y_test,predictions)
LR_F1_Score = f1_score(y_test,predictions)
LR_Log_Loss = log_loss(y_test,predict_proba)


LR_Accuracy_Score,LR_JaccardIndex,LR_F1_Score,LR_Log_Loss
# Out:
# (0.6030534351145038,
#  0.16932907348242812,
#  0.28961748633879786,
#  0.0018152889866352143)

# %% [markdown]
# ### SVM

# %% [markdown]
# #### Q16) Create and train a SVM model called SVM using the training data (`x_train`, `y_train`).

# %%
#Enter Your Code Below, Execute, and Save the Screenshot of the Final Output

# %%
SVM = svm.SVC()
SVM.fit(x_train,y_train)
# Out:
# SVC()

# %% [markdown]
# #### Q17) Now use the `predict` method on the testing data (`x_test`) and save it to the array `predictions`.

# %%
#Enter Your Code Below, Execute, and Save the Screenshot of the Final Output

# %%
predictions = SVM.predict(x_test)

# %% [markdown]
# #### Q18) Using the `predictions` and the `y_test` dataframe calculate the value for each metric using the appropriate function.

# %%
SVM_Accuracy_Score = accuracy_score(y_test,predictions)
SVM_JaccardIndex = jaccard_score(y_test,predictions)
SVM_F1_Score = f1_score(y_test,predictions)

SVM_Accuracy_Score,SVM_JaccardIndex,SVM_F1_Score
# Out:
# (0.9938931297709923, 0.978021978021978, 0.9888888888888888)

# %% [markdown]
# ### Report

# %% [markdown]
# #### Q19) Show the Accuracy,Jaccard Index,F1-Score and LogLoss in a tabular format using data frame for all of the above models.
#
# \*LogLoss is only for Logistic Regression Model

# %%
Report = pd.DataFrame({
    "models":["LinearRegression","KNN","DesicionTree","LogisticRegression","Support Vector Machines"],
    "Accuracy_Score":[f'MAE : {LinearRegression_MAE}', KNN_Accuracy_Score, Tree_Accuracy_Score, LR_Accuracy_Score, SVM_Accuracy_Score],
    "Jaccard_Index":[f'MSE : {LinearRegression_MSE}', KNN_JaccardIndex, Tree_JaccardIndex, LR_JaccardIndex, SVM_JaccardIndex],
    "F1_Score":[f'R2 : {LinearRegression_R2}', KNN_F1_Score, Tree_F1_Score, LR_F1_Score, SVM_F1_Score],
    "Log_Loss":['','','',LR_Log_Loss,'']
})

LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2
Report
# Out:
#                     models               Accuracy_Score  \
# 0         LinearRegression  MAE : 5.170588300181741e-16
# 1                      KNN                     0.851908
# 2             DesicionTree                          1.0
# 3       LogisticRegression                     0.603053
# 4  Support Vector Machines                     0.993893
#
#                  Jaccard_Index  F1_Score  Log_Loss
# 0  MSE : 4.271130427140983e-31  R2 : 1.0
# 1                        0.515  0.679868
# 2                          1.0       1.0
# 3                     0.169329  0.289617  0.001815
# 4                     0.978022  0.988889

# %% [markdown]
# <h2 id="Section_5">  How to submit </h2>
#
# <p>Once you complete your notebook you will have to share it. You can download the notebook by navigating to "File" and clicking on "Download" button.
#
# <p>This will save the (.ipynb) file on your computer. Once saved, you can upload this file in the "My Submission" tab, of the "Peer-graded Assignment" section.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# ### Other Contributors
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0232ENSkillsNetwork30654641-2022-01-01)

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description          |
# | ----------------- | ------- | ------------- | --------------------------- |
# | 2022-06-22        | 2.0     | Svitlana K.   | Deleted GridSearch and Mock |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
